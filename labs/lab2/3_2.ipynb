# %% [markdown]
# ## Задача 3.2
# [**Выборка:**](https://github.com/natasha/nerus) набор предложений на русском языке с указанием именованных сущностей (они же NE, named entity).
#
# Требуется:
# 1. Рассмотреть последовательность именованных и неименованных сущностей как марковскую модель. Определить оптимальный порядок марковской модели.
# 2. Обучить скрытую марковскую модель по выборке. Оценить точность предсказания, является ли слово именованной сущностью или нет, посчитать энтропию на выборке.
#
# *Важно:* в целях ускорения эксперимента рекомендуется взять первые 10 МБ текста из выборки.

# %%
from re import compile, Pattern
from sys import getsizeof
from nerus import load_nerus
from nltk.tag import hmm
import nltk
from collections import Counter
from more_itertools import take
from scipy.stats.distributions import chi2
from pandas import DataFrame
from seaborn import heatmap
from matplotlib.pyplot import figure
from numpy import transpose, log, sum as nsum, unique as nunique

# %%
nerus_dataset = load_nerus('data/nerus_lenta.conllu.gz')

# %%
def words_getter(rus_re, mb_count, dataset):
    """gets word and its pos for every word in dataset"""
    tokens = []
    megabyte_size = 1024 ** 2
    i = 0
    while getsizeof(tokens) < mb_count * megabyte_size:
        i += 1
        for sent in next(dataset).sents:
            for token in sent.tokens:
                word = token.text.lower()
                pos = token.pos
                if russian.match(word):
                    tokens.append((word, pos))
    return tokens

russian = compile('^[а-я]+$')

tokens = words_getter(russian, 10, nerus_dataset)
print(f"Number of tokens: {len(tokens)}")
# Out:
# Number of tokens: 1188214

# %%
tokens[:10]
# Out:
# [('по', 'ADP'),
#  ('социальным', 'ADJ'),
#  ('вопросам', 'NOUN'),
#  ('татьяна', 'PROPN'),
#  ('голикова', 'PROPN'),
#  ('рассказала', 'VERB'),
#  ('в', 'ADP'),
#  ('каких', 'DET'),
#  ('регионах', 'NOUN'),
#  ('россии', 'PROPN')]

# %% [markdown]
# Получим текст.

# %%
text = ' '.join(transpose(tokens)[0])
len(text), text[:100]
# Out:
# (8540838,
#  'по социальным вопросам татьяна голикова рассказала в каких регионах россии зафиксирована наиболее вы')

# %% [markdown]
# Сделаем словарь, в котором ключи это слова, а значения - это части речи.

# %%
vocab = {word: pos for word, pos in tokens}
len(vocab)
# Out:
# 98654

# %% [markdown]
# Посчитаем n-grams

# %%
def ngrams_and_prefix_counts(tokens, n_max):
    # словарь n-грамм и их частот
    ngrams_counts = {}
    # словарь n-граммных префиксов и их частот
    prefix_counts = {}
    
    n = len(tokens)
    for i in range(n_max):
        ngrams_counts[i + 1] = Counter([tuple(tokens[j : j + i + 1]) for j in range(n - i)])
        prefix_counts[i + 1] = Counter([tuple(tokens[j : j + i] + ['*']) for j in range(n - i)])

    return ngrams_counts, prefix_counts

# %%
ngram_counts, prefix_counts = ngrams_and_prefix_counts(tokens, 3)

# %%
def unigram_probas(ngram_counts):
    """
    gets probabilities of unigrams in text
    """
    p1 = {}
    n = sum(ngram_counts[1].values())
    for w in ngram_counts[1]:
        p1[w] = ngram_counts[1][w] / n
    return p1


def bigram_probas(ngram_counts, prefix_counts):
    """
    gets probabilities of bigrams in text
    """
    p2 = {}
    for w in ngram_counts[2]:
        pre_w = tuple([w[0]] + ['*'])
        p2[u'{1}|{0}'.format(*w)] = ngram_counts[2][w] / prefix_counts[2][pre_w]
    return p2


def trigram_probas(ngram_counts, prefix_counts):
    """
    gets probabilities of trigrams in text
    """
    p3 = {}
    for w in ngram_counts[3]:
        pre_w = w[:2] + tuple(['*'])
        p3[u'{2}|{1},{0}'.format(*w)] = ngram_counts[3][w] / prefix_counts[3][pre_w]
    return p3

# %% [markdown]
# Посчитаем вероятности для каждой из n-грамм для n=1,2,3. И посмотрим на случайные n-граммы и их вероятности.

# %%
def random_n_dict_items(d: dict, n: int) -> dict:
    """gets random n items of a sorted dict by values"""
    return [(d[x], x) for x in take(n, d)]

# %%
p1 = unigram_probas(ngram_counts)
random_n_dict_items(p1, 10)
# Out:
# [(0.010653804786006561, (('по', 'ADP'),)),
#  (1.1782389367571835e-05, (('социальным', 'ADJ'),)),
#  (0.00011024950051085074, (('вопросам', 'NOUN'),)),
#  (5.049595443245072e-05, (('татьяна', 'PROPN'),)),
#  (5.049595443245072e-06, (('голикова', 'PROPN'),)),
#  (0.0003686204673568903, (('рассказала', 'VERB'),)),
#  (0.05012985876281545, (('в', 'ADP'),)),
#  (3.366396962163381e-05, (('каких', 'DET'),)),
#  (0.00013718067620815778, (('регионах', 'NOUN'),)),
#  (0.003411001721912046, (('россии', 'PROPN'),))]

# %%
p2 = bigram_probas(ngram_counts, prefix_counts)
random_n_dict_items(p2, 10)
# Out:
# [(0.0004739710877636464, "('социальным', 'ADJ')|('по', 'ADP')"),
#  (0.14285714285714285, "('вопросам', 'NOUN')|('социальным', 'ADJ')"),
#  (0.015267175572519083, "('татьяна', 'PROPN')|('вопросам', 'NOUN')"),
#  (0.06666666666666667, "('голикова', 'PROPN')|('татьяна', 'PROPN')"),
#  (0.16666666666666666, "('рассказала', 'VERB')|('голикова', 'PROPN')"),
#  (0.0776255707762557, "('в', 'ADP')|('рассказала', 'VERB')"),
#  (0.0002014605892722236, "('каких', 'DET')|('в', 'ADP')"),
#  (0.075, "('регионах', 'NOUN')|('каких', 'DET')"),
#  (0.15337423312883436, "('россии', 'PROPN')|('регионах', 'NOUN')"),
#  (0.0002467308166790032, "('зафиксирована', 'VERB')|('россии', 'PROPN')")]

# %%
p3 = trigram_probas(ngram_counts, prefix_counts)
random_n_dict_items(p3, 10)
# Out:
# [(0.3333333333333333,
#   "('вопросам', 'NOUN')|('социальным', 'ADJ'),('по', 'ADP')"),
#  (1.0, "('татьяна', 'PROPN')|('вопросам', 'NOUN'),('социальным', 'ADJ')"),
#  (1.0, "('голикова', 'PROPN')|('татьяна', 'PROPN'),('вопросам', 'NOUN')"),
#  (0.25, "('рассказала', 'VERB')|('голикова', 'PROPN'),('татьяна', 'PROPN')"),
#  (1.0, "('в', 'ADP')|('рассказала', 'VERB'),('голикова', 'PROPN')"),
#  (0.029411764705882353,
#   "('каких', 'DET')|('в', 'ADP'),('рассказала', 'VERB')"),
#  (0.16666666666666666, "('регионах', 'NOUN')|('каких', 'DET'),('в', 'ADP')"),
#  (0.6666666666666666,
#   "('россии', 'PROPN')|('регионах', 'NOUN'),('каких', 'DET')"),
#  (0.04, "('зафиксирована', 'VERB')|('россии', 'PROPN'),('регионах', 'NOUN')"),
#  (1.0, "('наиболее', 'ADV')|('зафиксирована', 'VERB'),('россии', 'PROPN')")]

# %%
def chi2_statistic(p_small, p_big, tokens, model_type: str):
    """
    gets chi2 stat for the hypothesis that we can reduce
    the bigram model to the monogram one
    """
    stat_small = []
    stat_big = []
    n = len(tokens)
    for i in range(n - 2):
        if model_type == "3_to_2":
            w = tokens[i : i + 3]
            ngram_big = '{2}|{1},{0}'.format(*w)
            ngram_small = '{1}|{0}'.format(*w)
        elif model_type == "2_to_1":
            w = tokens[i : i + 2]
            ngram_big = '{1}|{0}'.format(*w)
            ngram_small = '{0}'.format(*w)
        else:
            raise ValueError("unrecognized model type")

        try:
            stat_small.append(log(p_small[ngram_small]))
        except KeyError:
            stat_small.append(log(1e-20))
        try:
            stat_big.append(log(p_big[ngram_big]))
        except KeyError:
            stat_big.append(log(1e-20))
    return - 2 * nsum(stat_small) + 2 * nsum(stat_big)

# %% [markdown]
# Посмотрим, можем ли мы использовать би-граммы вместо три-грамм

# %%
stat_32 = chi2_statistic(p2, p3, tokens, model_type="3_to_2")
print(f'p-value of a chi2 test that we can reduce tri-gram to bi-gram model: {1 - chi2(len(p3) * ((len(p3) - 1) ** 2) - 1).cdf(stat_32):.2f}')
# Out:
# p-value of a chi2 test that we can reduce tri-gram to bi-gram model: 1.00

# %% [markdown]
# Посмотрим, можем ли мы использовать монограммы вместо три-грамм

# %%
stat_21 = chi2_statistic(p1, p2, tokens, model_type="2_to_1")
print(f'p-value of a chi2 test that we can reduce bi-gram to mono-gram model: {1 - chi2(len(p2) * ((len(p2) - 1) ** 2) - 1).cdf(stat_21):.2f}')
# Out:
# p-value of a chi2 test that we can reduce bi-gram to mono-gram model: 1.00

# %% [markdown]
# оптимальная модель пользуется только монограммами

# %%
train_data = words_getter(russian, 10, nerus_dataset)

# %%
trainer = hmm.HiddenMarkovModelTrainer([])
tagger = trainer.train_supervised([train_data])

# %%
train_res = tagger.test([train_data[:len(train_data) // 200]], verbose=True)
# Out:
# Test: житель/NOUN австралии/PROPN убил/VERB питона/NOUN длиной/NOUN более/ADV четырех/NUM метров/NOUN в/ADP попытке/NOUN спасти/VERB своего/DET внука/NOUN об/ADP этом/PRON сообщает/VERB историю/NOUN о/ADP спасении/NOUN рассказала/VERB мать/NOUN пострадавшего/VERB мальчика/NOUN аманда/PROPN ратленд/PROPN во/ADP время/NOUN нападения/NOUN наиш/PROPN играл/VERB вместе/ADV с/ADP трехлетней/ADJ сестрой/NOUN на/ADP веранде/NOUN дома/NOUN в/ADP северном/ADJ квинсленде/PROPN ратленд/PROPN посмотрела/VERB на/ADP потерянное/ADJ лицо/NOUN дочери/NOUN и/CCONJ поняла/VERB что/SCONJ с/ADP детьми/NOUN происходит/VERB неладное/ADJ выйдя/VERB на/ADP улицу/NOUN она/PRON увидела/VERB что/SCONJ питон/NOUN длиной/NOUN метра/NOUN обвился/VERB вокруг/ADP ее/DET маленького/ADJ сына/NOUN змея/NOUN также/ADV начала/VERB кусать/VERB его/PRON за/ADP правую/ADJ руку/NOUN женщина/NOUN не/PART смогла/VERB самостоятельно/ADV избавиться/VERB от/ADP рептилии/NOUN и/CCONJ позвала/VERB на/ADP помощь/NOUN своего/DET отца/NOUN рона/PROPN ратленда/PROPN тем/DET временем/NOUN змея/NOUN начала/VERB усиливать/VERB хватку/NOUN примчавшийся/VERB мужчина/NOUN закричал/VERB что/SCONJ ему/PRON нужен/ADJ нож/NOUN а/CCONJ затем/ADV ударил/VERB им/PRON питона/NOUN и/CCONJ освободил/VERB ребенка/NOUN наиш/NOUN был/AUX доставлен/VERB в/ADP больницу/NOUN с/ADP укусами/NOUN и/CCONJ синяками/NOUN змея/NOUN умерла/VERB от/ADP полученных/VERB травм/NOUN ратленд/PROPN уверена/ADJ что/SCONJ перед/ADP нападением/NOUN питон/NOUN следил/VERB за/ADP ребенком/NOUN в/ADP течение/NOUN нескольких/NUM недель/NOUN издание/NOUN отмечает/VERB что/SCONJ в/ADP случае/NOUN если/SCONJ бы/AUX к/ADP спасению/NOUN мальчика/NOUN не/PART подключился/VERB его/PRON дед/NOUN змея/NOUN бы/AUX съела/VERB его/PRON аметистовые/ADJ питоны/NOUN самые/ADJ крупные/ADJ змеи/NOUN живущие/VERB в/ADP австралии/PROPN достигают/VERB восьми/NUM метров/NOUN в/ADP длину/NOUN около/ADP тысячи/NOUN подмосковных/ADJ предпринимателей/NOUN приняли/VERB участие/NOUN в/ADP образовательных/ADJ семинарах/NOUN правовая/ADJ и/CCONJ финансовая/ADJ безопасность/NOUN бизнеса/NOUN с/ADP начала/NOUN года/NOUN об/ADP этом/PRON сообщил/VERB заместитель/NOUN председателя/NOUN регионального/ADJ правительства/NOUN денис/PROPN буцаев/PROPN передает/VERB корреспондент/NOUN ленты/NOUN ру/NOUN в/ADP понедельник/NOUN октября/NOUN в/ADP этом/DET году/NOUN семинары/NOUN по/ADP правовой/ADJ и/CCONJ финансовой/ADJ безопасности/NOUN бизнеса/NOUN проведены/VERB уже/ADV в/ADP городах/NOUN московской/ADJ области/NOUN мы/PRON видим/VERB большой/ADJ интерес/NOUN предпринимателей/NOUN региона/NOUN к/ADP ним/PRON до/ADP конца/NOUN года/NOUN пройдет/VERB еще/ADV четыре/NUM семинара/NOUN в/ADP муниципалитетах/NOUN рассказал/VERB буцаев/PROPN в/ADP ходе/NOUN семинаров/NOUN отвечают/VERB на/ADP вопросы/NOUN связанные/VERB в/ADP частности/NOUN с/ADP получением/NOUN федеральных/ADJ и/CCONJ региональных/ADJ мер/NOUN поддержки/NOUN проверками/NOUN органов/NOUN в/ADP середине/NOUN сентября/NOUN буцаев/PROPN сообщил/VERB что/SCONJ с/ADP начала/NOUN года/NOUN в/ADP регионе/NOUN было/AUX зарегистрировано/VERB свыше/ADP тысячи/NOUN новых/ADJ предпринимателей/NOUN ранее/ADV губернатор/NOUN области/NOUN андрей/PROPN воробьев/PROPN заявил/VERB о/ADP необходимости/NOUN поддержки/NOUN предпринимательских/ADJ инициатив/NOUN он/PRON отметил/VERB что/SCONJ в/ADP регионе/NOUN уже/ADV действуют/VERB различные/ADJ программы/NOUN для/ADP молодых/ADJ бизнесменов/NOUN однако/ADV власти/NOUN не/PART намерены/ADJ останавливаться/VERB на/ADP достигнутом/VERB по/ADP его/DET словам/NOUN молодые/ADJ и/CCONJ инициативные/ADJ граждане/NOUN могут/VERB вывести/VERB экономику/NOUN подмосковья/PROPN на/ADP новый/ADJ уровень/NOUN уралвагонзавод/PROPN испытал/VERB танк/NOUN на/ADP герметичность/NOUN и/CCONJ утопил/VERB его/PRON в/ADP бассейне/NOUN ролик/NOUN с/ADP тестами/NOUN опубликован/VERB на/ADP отмечается/VERB что/SCONJ для/ADP погружения/NOUN был/AUX выбран/VERB случайный/ADJ танк/NOUN из/ADP пар ...
#
# Untagged: житель австралии убил питона длиной более четырех метров в попытке спасти своего внука об этом сообщает историю о спасении рассказала мать пострадавшего мальчика аманда ратленд во время нападения наиш играл вместе с трехлетней сестрой на веранде дома в северном квинсленде ратленд посмотрела на потерянное лицо дочери и поняла что с детьми происходит неладное выйдя на улицу она увидела что питон длиной метра обвился вокруг ее маленького сына змея также начала кусать его за правую руку женщина не смогла самостоятельно избавиться от рептилии и позвала на помощь своего отца рона ратленда тем временем змея начала усиливать хватку примчавшийся мужчина закричал что ему нужен нож а затем ударил им питона и освободил ребенка наиш был доставлен в больницу с укусами и синяками змея умерла от полученных травм ратленд уверена что перед нападением питон следил за ребенком в течение нескольких недель издание отмечает что в случае если бы к спасению мальчика не подключился его дед змея бы съела его аметистовые питоны самые крупные змеи живущие в австралии достигают восьми метров в длину около тысячи подмосковных предпринимателей приняли участие в образовательных семинарах правовая и финансовая безопасность бизнеса с начала года об этом сообщил заместитель председателя регионального правительства денис буцаев передает корреспондент ленты ру в понедельник октября в этом году семинары по правовой и финансовой безопасности бизнеса проведены уже в городах московской области мы видим большой интерес предпринимателей региона к ним до конца года пройдет еще четыре семинара в муниципалитетах рассказал буцаев в ходе семинаров отвечают на вопросы связанные в частности с получением федеральных и региональных мер поддержки проверками органов в середине сентября буцаев сообщил что с начала года в регионе было зарегистрировано свыше тысячи новых предпринимателей ранее губернатор области андрей воробьев заявил о необходимости поддержки предпринимательских инициатив он отметил что в регионе уже действуют различные программы для молодых бизнесменов однако власти не намерены останавливаться на достигнутом по его словам молодые и инициативные граждане могут вывести экономику подмосковья на новый уровень уралвагонзавод испытал танк на герметичность и утопил его в бассейне ролик с тестами опубликован на отмечается что для погружения был выбран случайный танк из партии на глубине пять метров он провел минут во время испытаний трое специалистов проверяют танк на наличие течей испытания считаются пройденными если за это время в танк налилось не более литров воды из затопленного на полигоне вытекло около полулитра воды в городе бокситогорске ленинградской области ученица старших классов нанесла ножевые ранения двум студентам местного техникума об этом в понедельник октября сообщил источник в правоохранительных органах передает тасс инцидент произошел вечером октября между двумя первокурсниками и школьницей завязалась драка недалеко от магазина косметики на улице вишнякова рассказали в агентстве девушка использовала в ходе конфликта нож в результате инцидента оба молодых человека были госпитализированы с ранами позднее их отпустили на амбулаторное лечение также отмечается что следственные органы проводят проверку по факту произошедшего в феврале в сети появилось видео на котором школьница из рязанской области бьет ногами своего как удалось выяснить мальчик оскорбил свою одноклассницу и она решила его проучить пострадавший попал в больницу с переломом ребра и сотрясением мозга норвежский лыжник петтер нортуг был изолирован от основной команды на сборах в итальянском валь сеналесе по причине болезни об этом сообщает спортсмен был отправлен в отель где базируется сборная россии по лыжным гонкам в нем также проживают спортсмены из швейцарии и финляндии если они боятся что нортуг заразит то это очень странное решение тут рядом очень много других гостиниц у нас тоже один атлет заболел и мы переселили его вниз с высоты в метров на уровень метров я не врач но уверен ч ...
#
# HMM-tagged: житель/NOUN австралии/PROPN убил/VERB питона/NOUN длиной/NOUN более/ADV четырех/NUM метров/NOUN в/ADP попытке/NOUN спасти/VERB своего/DET внука/NOUN об/ADP этом/PRON сообщает/VERB историю/NOUN о/ADP спасении/NOUN рассказала/VERB мать/NOUN пострадавшего/NOUN мальчика/NOUN аманда/PROPN ратленд/PROPN во/ADP время/NOUN нападения/NOUN наиш/PROPN играл/VERB вместе/ADV с/ADP трехлетней/ADJ сестрой/NOUN на/ADP веранде/NOUN дома/NOUN в/ADP северном/ADJ квинсленде/PROPN ратленд/PROPN посмотрела/VERB на/ADP потерянное/ADJ лицо/NOUN дочери/NOUN и/CCONJ поняла/VERB что/SCONJ с/ADP детьми/NOUN происходит/VERB неладное/ADJ выйдя/VERB на/ADP улицу/NOUN она/PRON увидела/VERB что/SCONJ питон/NOUN длиной/NOUN метра/NOUN обвился/VERB вокруг/ADP ее/DET маленького/ADJ сына/NOUN змея/NOUN также/ADV начала/VERB кусать/VERB его/PRON за/ADP правую/ADJ руку/NOUN женщина/NOUN не/PART смогла/VERB самостоятельно/ADV избавиться/VERB от/ADP рептилии/NOUN и/CCONJ позвала/VERB на/ADP помощь/NOUN своего/DET отца/NOUN рона/PROPN ратленда/PROPN тем/PRON временем/NOUN змея/NOUN начала/NOUN усиливать/VERB хватку/NOUN примчавшийся/VERB мужчина/NOUN закричал/VERB что/SCONJ ему/PRON нужен/ADJ нож/NOUN а/CCONJ затем/ADV ударил/VERB им/PRON питона/NOUN и/CCONJ освободил/VERB ребенка/NOUN наиш/PROPN был/AUX доставлен/VERB в/ADP больницу/NOUN с/ADP укусами/NOUN и/CCONJ синяками/NOUN змея/NOUN умерла/VERB от/ADP полученных/VERB травм/NOUN ратленд/PROPN уверена/ADJ что/SCONJ перед/ADP нападением/NOUN питон/NOUN следил/VERB за/ADP ребенком/NOUN в/ADP течение/NOUN нескольких/NUM недель/NOUN издание/NOUN отмечает/VERB что/SCONJ в/ADP случае/NOUN если/SCONJ бы/AUX к/ADP спасению/NOUN мальчика/NOUN не/PART подключился/VERB его/DET дед/NOUN змея/NOUN бы/AUX съела/VERB его/DET аметистовые/ADJ питоны/NOUN самые/ADJ крупные/ADJ змеи/NOUN живущие/VERB в/ADP австралии/PROPN достигают/VERB восьми/NUM метров/NOUN в/ADP длину/NOUN около/ADP тысячи/NOUN подмосковных/ADJ предпринимателей/NOUN приняли/VERB участие/NOUN в/ADP образовательных/ADJ семинарах/NOUN правовая/ADJ и/CCONJ финансовая/ADJ безопасность/NOUN бизнеса/NOUN с/ADP начала/NOUN года/NOUN об/ADP этом/PRON сообщил/VERB заместитель/NOUN председателя/NOUN регионального/ADJ правительства/NOUN денис/PROPN буцаев/PROPN передает/VERB корреспондент/NOUN ленты/NOUN ру/NOUN в/ADP понедельник/NOUN октября/NOUN в/ADP этом/PRON году/NOUN семинары/NOUN по/ADP правовой/ADJ и/CCONJ финансовой/ADJ безопасности/NOUN бизнеса/NOUN проведены/VERB уже/ADV в/ADP городах/NOUN московской/ADJ области/NOUN мы/PRON видим/VERB большой/ADJ интерес/NOUN предпринимателей/NOUN региона/NOUN к/ADP ним/PRON до/ADP конца/NOUN года/NOUN пройдет/VERB еще/ADV четыре/NUM семинара/NOUN в/ADP муниципалитетах/NOUN рассказал/VERB буцаев/PROPN в/ADP ходе/NOUN семинаров/NOUN отвечают/VERB на/ADP вопросы/NOUN связанные/VERB в/ADP частности/NOUN с/ADP получением/NOUN федеральных/ADJ и/CCONJ региональных/ADJ мер/NOUN поддержки/NOUN проверками/NOUN органов/NOUN в/ADP середине/NOUN сентября/NOUN буцаев/PROPN сообщил/VERB что/SCONJ с/ADP начала/NOUN года/NOUN в/ADP регионе/NOUN было/AUX зарегистрировано/VERB свыше/ADP тысячи/NOUN новых/ADJ предпринимателей/NOUN ранее/ADV губернатор/NOUN области/NOUN андрей/PROPN воробьев/PROPN заявил/VERB о/ADP необходимости/NOUN поддержки/NOUN предпринимательских/ADJ инициатив/NOUN он/PRON отметил/VERB что/SCONJ в/ADP регионе/NOUN уже/ADV действуют/VERB различные/ADJ программы/NOUN для/ADP молодых/ADJ бизнесменов/NOUN однако/ADV власти/NOUN не/PART намерены/ADJ останавливаться/VERB на/ADP достигнутом/VERB по/ADP его/DET словам/NOUN молодые/ADJ и/CCONJ инициативные/ADJ граждане/NOUN могут/VERB вывести/VERB экономику/NOUN подмосковья/PROPN на/ADP новый/ADJ уровень/NOUN уралвагонзавод/PROPN испытал/VERB танк/NOUN на/ADP герметичность/NOUN и/CCONJ утопил/VERB его/PRON в/ADP бассейне/NOUN ролик/NOUN с/ADP тестами/NOUN опубликован/VERB на/ADP отмечается/VERB что/SCONJ для/ADP погружения/NOUN был/AUX выбран/VERB случайный/ADJ танк/NOUN из/ ...
#
# Entropy: 313.633564447747
#
# ------------------------------------------------------------
# accuracy over 5941 tokens: 98.57

# %%
test_data = words_getter(russian, 0.5, nerus_dataset)

# %%
test_res = tagger.test([test_data], verbose=True)
# Out:
# Test: австралийский/ADJ бренд/NOUN выпустил/VERB кружевное/ADJ нижнее/ADJ белье/NOUN для/ADP мужчин/NOUN об/ADP этом/PRON сообщает/VERB коллекция/NOUN включает/VERB себя/PRON множество/NOUN моделей/NOUN бюстгальтеров/NOUN и/CCONJ трусов/NOUN изготовленных/VERB из/ADP шелка/NOUN сатина/NOUN и/CCONJ кружева/NOUN все/DET модели/NOUN представлены/VERB в/ADP пяти/NUM размерах/NOUN от/ADP до/ADP моя/DET девушка/NOUN в/ADP восторге/NOUN когда/SCONJ я/PRON надеваю/VERB бюстгальтер/NOUN и/CCONJ трусы/NOUN в/ADP тон/NOUN написал/VERB довольный/ADJ клиент/NOUN в/ADP отзывах/NOUN к/ADP одному/NUM из/ADP топов/NOUN они/PRON потрясающие/ADJ очень/ADV качественные/ADJ и/CCONJ сексуальные/ADJ одобрил/VERB другой/ADJ покупатель/NOUN белье/NOUN продается/VERB на/ADP официальном/ADJ сайте/NOUN бренда/NOUN по/ADP цене/NOUN от/ADP до/ADP долларов/NOUN в/ADP августе/NOUN французская/ADJ компания/NOUN представила/VERB свою/DET первую/ADJ коллекцию/NOUN макияжа/NOUN для/ADP мужчин/NOUN в/ADP линию/NOUN вошли/VERB четыре/NUM оттенка/NOUN тонального/ADJ флюида/NOUN бесцветный/ADJ бальзам/NOUN для/ADP губ/NOUN и/CCONJ карандаш/NOUN для/ADP бровей/NOUN в/ADP двух/NUM оттенках/NOUN и/CCONJ президент/NOUN белоруссии/PROPN александр/PROPN лукашенко/PROPN раскритиковал/VERB освещение/NOUN белорусской/ADJ политики/NOUN российскими/ADJ журналистами/NOUN и/CCONJ назвал/VERB их/PRON идиотами/NOUN об/ADP этом/PRON он/PRON заявил/VERB в/ADP интервью/NOUN телеканалу/NOUN беларусь/PROPN я/PRON может/VERB больше/ADV себе/PRON позволяю/VERB открыто/ADV говорить/VERB об/ADP этом/PRON это/PRON уже/ADV в/ADP силу/NOUN моего/DET характера/NOUN здесь/ADV нет/VERB ничего/PRON подспудного/ADJ или/CCONJ гадких/ADJ мыслей/NOUN о/ADP которых/PRON иногда/ADV пишут/VERB особенно/ADV в/ADP российской/ADJ федерации/PROPN разного/ADJ рода/NOUN идиоты/NOUN я/PRON их/PRON иначе/ADV не/PART назову/VERB заявил/VERB белорусский/ADJ президент/NOUN так/ADV лукашенко/PROPN отреагировал/VERB на/ADP обвинение/NOUN российских/ADJ сми/NOUN в/ADP использовании/NOUN новых/ADJ антироссийских/ADJ санкций/NOUN для/ADP того/PRON чтобы/SCONJ потребовать/VERB от/ADP россии/PROPN ранее/ADV белорусский/ADJ лидер/NOUN уже/ADV критиковал/VERB российские/ADJ сми/NOUN за/ADP неправильное/ADJ по/ADP его/DET мнению/NOUN освещение/NOUN белорусской/ADJ политики/NOUN в/ADP июне/NOUN этого/DET года/NOUN он/PRON обрушился/VERB с/ADP критикой/NOUN на/ADP ленту/NOUN ру/NOUN за/ADP статью/NOUN о/ADP переписывании/NOUN истории/NOUN кроме/ADP того/PRON в/ADP июне/NOUN на/ADP ленте/NOUN ру/NOUN вышла/VERB статья/NOUN о/ADP том/PRON как/ADV александр/PROPN лукашенко/PROPN использует/VERB санкционные/ADJ войны/NOUN между/ADP россией/PROPN и/CCONJ ес/PROPN для/ADP организации/NOUN контрабандных/ADJ поставок/NOUN в/ADP рф/PROPN и/CCONJ личного/ADJ обогащения/NOUN бывший/ADJ исполняющий/VERB обязанности/NOUN министра/NOUN культуры/NOUN и/CCONJ туризма/NOUN самопровозглашенной/ADJ донецкой/ADJ народной/ADJ республики/NOUN днр/PROPN юрий/PROPN лекстутес/PROPN был/AUX завербован/VERB украинскими/ADJ спецслужбами/NOUN и/CCONJ попросил/VERB их/PRON эвакуировать/VERB себя/PRON на/ADP контролируемую/VERB киевом/PROPN территорию/NOUN об/ADP этом/PRON говорится/VERB в/ADP сюжете/NOUN тсн/PROPN по/ADP словам/NOUN лекстутеса/PROPN в/ADP году/NOUN он/PRON должен/ADJ был/AUX возглавить/VERB самопровозглашенную/ADJ республику/NOUN после/ADP свержения/NOUN руководителя/NOUN днр/PROPN александра/PROPN захарченко/PROPN лекстутес/NOUN утверждает/VERB что/SCONJ некий/DET сотрудник/NOUN главного/ADJ разведывательного/ADJ управления/NOUN гру/PROPN по/ADP прозвищу/NOUN иваныч/PROPN предлагал/VERB ему/PRON силовую/ADJ поддержку/NOUN в/ADP том/DET случае/NOUN если/SCONJ он/PRON согласится/VERB возглавить/VERB днр/PROPN помешала/VERB восхождению/NOUN лекстутеса/PROPN федеральная/ADJ служба/NOUN безопасности/NOUN фсб/PROPN по/ADP его/DET словам/NOUN в/ADP кремле/PROPN за/ADP донбасс/PROPN идет/VERB настоящая/ADJ война/NOUN между/ADP фсб/PROPN и/CCONJ  ...
#
# Untagged: австралийский бренд выпустил кружевное нижнее белье для мужчин об этом сообщает коллекция включает себя множество моделей бюстгальтеров и трусов изготовленных из шелка сатина и кружева все модели представлены в пяти размерах от до моя девушка в восторге когда я надеваю бюстгальтер и трусы в тон написал довольный клиент в отзывах к одному из топов они потрясающие очень качественные и сексуальные одобрил другой покупатель белье продается на официальном сайте бренда по цене от до долларов в августе французская компания представила свою первую коллекцию макияжа для мужчин в линию вошли четыре оттенка тонального флюида бесцветный бальзам для губ и карандаш для бровей в двух оттенках и президент белоруссии александр лукашенко раскритиковал освещение белорусской политики российскими журналистами и назвал их идиотами об этом он заявил в интервью телеканалу беларусь я может больше себе позволяю открыто говорить об этом это уже в силу моего характера здесь нет ничего подспудного или гадких мыслей о которых иногда пишут особенно в российской федерации разного рода идиоты я их иначе не назову заявил белорусский президент так лукашенко отреагировал на обвинение российских сми в использовании новых антироссийских санкций для того чтобы потребовать от россии ранее белорусский лидер уже критиковал российские сми за неправильное по его мнению освещение белорусской политики в июне этого года он обрушился с критикой на ленту ру за статью о переписывании истории кроме того в июне на ленте ру вышла статья о том как александр лукашенко использует санкционные войны между россией и ес для организации контрабандных поставок в рф и личного обогащения бывший исполняющий обязанности министра культуры и туризма самопровозглашенной донецкой народной республики днр юрий лекстутес был завербован украинскими спецслужбами и попросил их эвакуировать себя на контролируемую киевом территорию об этом говорится в сюжете тсн по словам лекстутеса в году он должен был возглавить самопровозглашенную республику после свержения руководителя днр александра захарченко лекстутес утверждает что некий сотрудник главного разведывательного управления гру по прозвищу иваныч предлагал ему силовую поддержку в том случае если он согласится возглавить днр помешала восхождению лекстутеса федеральная служба безопасности фсб по его словам в кремле за донбасс идет настоящая война между фсб и гру побеждает в этой борьбе фсб ее ставленник александр захарченко руководит республикой с года в декабре года лекстутес был арестован в донецке по версии генпрокуратуры днр он вместе с батальоном восток завладел автомобилями донецкого театра донецкого театра оперы и балета имени соловьяненко и академического ансамбля песни и танца донбасс для использования в своих корыстных целях за несколько месяцев до ареста лекстутес намеревался принять участие в выборах главы днр однако не был зарегистрирован кандидатом поскольку не предоставил в цик республики подписные листы председатель федеральной автономии российских цыган надежда деметр связала рост негативного отношения к цыганам в россии с необъективным освещением в сми событий связанных с диаспорой ее цитирует радиостанция говорит москва деметр поразили данные опроса указывающие на то что процента россиян считают цыган нежелательным этносом проживание представителей которого в стране нужно ограничить думаю это оттого что мы неправильно ведем себя в отношении средств массовой информации и сми тоже к сожалению ведут себя соответствующим образом инженер звездного городка олег эрденко эти люди совершенно отсутствуют в прессе нужно больше давать материалов о том что цыгане не мигранты полагает председатель организации по ее словам в опросе цыган приравняли к мигрантам однако цыгане живут в россии лет и считать их мигрантами неправильно они граждане россии напомнила она добавив что мигрирующих цыган в россии очень мало негативный имидж у цыган сформировался отсутствия государственной структуры которая поддерживала бы диаспору думаю что дело в средс ...
#
# HMM-tagged: австралийский/NOUN бренд/NOUN выпустил/NOUN кружевное/NOUN нижнее/NOUN белье/NOUN для/NOUN мужчин/NOUN об/NOUN этом/NOUN сообщает/NOUN коллекция/NOUN включает/NOUN себя/NOUN множество/NOUN моделей/NOUN бюстгальтеров/NOUN и/NOUN трусов/NOUN изготовленных/NOUN из/NOUN шелка/NOUN сатина/NOUN и/NOUN кружева/NOUN все/NOUN модели/NOUN представлены/NOUN в/NOUN пяти/NOUN размерах/NOUN от/NOUN до/NOUN моя/NOUN девушка/NOUN в/NOUN восторге/NOUN когда/NOUN я/NOUN надеваю/NOUN бюстгальтер/NOUN и/NOUN трусы/NOUN в/NOUN тон/NOUN написал/NOUN довольный/NOUN клиент/NOUN в/NOUN отзывах/NOUN к/NOUN одному/NOUN из/NOUN топов/NOUN они/NOUN потрясающие/NOUN очень/NOUN качественные/NOUN и/NOUN сексуальные/NOUN одобрил/NOUN другой/NOUN покупатель/NOUN белье/NOUN продается/NOUN на/NOUN официальном/NOUN сайте/NOUN бренда/NOUN по/NOUN цене/NOUN от/NOUN до/NOUN долларов/NOUN в/NOUN августе/NOUN французская/NOUN компания/NOUN представила/NOUN свою/NOUN первую/NOUN коллекцию/NOUN макияжа/NOUN для/NOUN мужчин/NOUN в/NOUN линию/NOUN вошли/NOUN четыре/NOUN оттенка/NOUN тонального/NOUN флюида/NOUN бесцветный/NOUN бальзам/NOUN для/NOUN губ/NOUN и/NOUN карандаш/NOUN для/NOUN бровей/NOUN в/NOUN двух/NOUN оттенках/NOUN и/NOUN президент/NOUN белоруссии/NOUN александр/NOUN лукашенко/NOUN раскритиковал/NOUN освещение/NOUN белорусской/NOUN политики/NOUN российскими/NOUN журналистами/NOUN и/NOUN назвал/NOUN их/NOUN идиотами/NOUN об/NOUN этом/NOUN он/NOUN заявил/NOUN в/NOUN интервью/NOUN телеканалу/NOUN беларусь/NOUN я/NOUN может/NOUN больше/NOUN себе/NOUN позволяю/NOUN открыто/NOUN говорить/NOUN об/NOUN этом/NOUN это/NOUN уже/NOUN в/NOUN силу/NOUN моего/NOUN характера/NOUN здесь/NOUN нет/NOUN ничего/NOUN подспудного/NOUN или/NOUN гадких/NOUN мыслей/NOUN о/NOUN которых/NOUN иногда/NOUN пишут/NOUN особенно/NOUN в/NOUN российской/NOUN федерации/NOUN разного/NOUN рода/NOUN идиоты/NOUN я/NOUN их/NOUN иначе/NOUN не/NOUN назову/NOUN заявил/NOUN белорусский/NOUN президент/NOUN так/NOUN лукашенко/NOUN отреагировал/NOUN на/NOUN обвинение/NOUN российских/NOUN сми/NOUN в/NOUN использовании/NOUN новых/NOUN антироссийских/NOUN санкций/NOUN для/NOUN того/NOUN чтобы/NOUN потребовать/NOUN от/NOUN россии/NOUN ранее/NOUN белорусский/NOUN лидер/NOUN уже/NOUN критиковал/NOUN российские/NOUN сми/NOUN за/NOUN неправильное/NOUN по/NOUN его/NOUN мнению/NOUN освещение/NOUN белорусской/NOUN политики/NOUN в/NOUN июне/NOUN этого/NOUN года/NOUN он/NOUN обрушился/NOUN с/NOUN критикой/NOUN на/NOUN ленту/NOUN ру/NOUN за/NOUN статью/NOUN о/NOUN переписывании/NOUN истории/NOUN кроме/NOUN того/NOUN в/NOUN июне/NOUN на/NOUN ленте/NOUN ру/NOUN вышла/NOUN статья/NOUN о/NOUN том/NOUN как/NOUN александр/NOUN лукашенко/NOUN использует/NOUN санкционные/NOUN войны/NOUN между/NOUN россией/NOUN и/NOUN ес/NOUN для/NOUN организации/NOUN контрабандных/NOUN поставок/NOUN в/NOUN рф/NOUN и/NOUN личного/NOUN обогащения/NOUN бывший/NOUN исполняющий/NOUN обязанности/NOUN министра/NOUN культуры/NOUN и/NOUN туризма/NOUN самопровозглашенной/NOUN донецкой/NOUN народной/NOUN республики/NOUN днр/NOUN юрий/NOUN лекстутес/NOUN был/NOUN завербован/NOUN украинскими/NOUN спецслужбами/NOUN и/NOUN попросил/NOUN их/NOUN эвакуировать/NOUN себя/NOUN на/NOUN контролируемую/NOUN киевом/NOUN территорию/NOUN об/NOUN этом/NOUN говорится/NOUN в/NOUN сюжете/NOUN тсн/NOUN по/NOUN словам/NOUN лекстутеса/NOUN в/NOUN году/NOUN он/NOUN должен/NOUN был/NOUN возглавить/NOUN самопровозглашенную/NOUN республику/NOUN после/NOUN свержения/NOUN руководителя/NOUN днр/NOUN александра/NOUN захарченко/NOUN лекстутес/NOUN утверждает/NOUN что/NOUN некий/NOUN сотрудник/NOUN главного/NOUN разведывательного/NOUN управления/NOUN гру/NOUN по/NOUN прозвищу/NOUN иваныч/NOUN предлагал/NOUN ему/NOUN силовую/NOUN поддержку/NOUN в/NOUN том/NOUN случае/NOUN если/NOUN он/NOUN согласится/NOUN возглавить/NOUN днр/NOUN помешала/NOUN восхождению/NOUN лекстутеса/NOUN федеральная/NOUN служба/NOUN безопасности/NOUN фсб/NOUN по/NOUN его/NOUN словам/NOUN в/NOUN кремле/NOU ...
#
# Entropy: -3.362999999999958e+303
#
# ------------------------------------------------------------
# accuracy over 62538 tokens: 33.94

# %% [markdown]
# Всё работает довольно плохо, возможно, недостаточный объём обучающей выборки для модели.
